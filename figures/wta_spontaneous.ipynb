# %%
# %matplotlib inline
import wta_spontaneous

# %%
CONFIG = {
    
    'SEED': None,
    'DURATION': 500,
    
    'TAU': 5,
    'V_REST': 0,
    'THRESHOLD': 4,
    'STEEPNESS': 2.5,
    'NOISE_LEVEL': 2,
    
    'W_FS': 2.3,
    'W_FF': 9,
    'W_FI': -6,
    'W_XFI': -12,
    'W_IF': 10,
    
    'SWITCH_DRIVE': 10,
    
    'FONT_SIZE': 20,
    
}

# %%
wta_spontaneous.main(CONFIG)
