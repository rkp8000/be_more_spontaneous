# %%
# %matplotlib inline
import wta_spontaneous

# %%
CONFIG = {
    
    'SEED': None,
    'DURATION': 200,
    
    'TAU': 5,
    'V_REST': 0,
    'THRESHOLD': 4,
    'STEEPNESS': 2.5,
    'NOISE_LEVEL': 3,
    
    'W_FS': 3,
    'W_FF': 5.5,
    'W_FI': -3,
    
    'SWITCH_DRIVE': 10,
    
    'FONT_SIZE': 20,
    
}

# %%
wta_spontaneous.main(CONFIG)
