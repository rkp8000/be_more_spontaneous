# %%
# %matplotlib inline
import softmax_random_basic_properties

# %%
CONFIG_NETWORK = {
    'SEED': 4,
    
    'N_NODES': 50,
    'P_CXN': .04,
    
    'W_STRONG': 2,
    
    'GAIN': 6,
    'REFRACTORY_STRENGTH': -1,
    
    'PATH_LENGTH': 3,
    'TRIAL_LENGTH': 5,
    'MAX_ATTEMPTS': 10,
    
    'SAVE_FILE_NAME': 'softmax_random_network.npy'
}

# %%
softmax_random_basic_properties.make_and_save_network(CONFIG_NETWORK)
# Out:
# Trial number 0
# Min summed path tree size: 3.
# node_0 before reordering: 6
# node_1 before reordering: 48
# node_0_path_tree before reordering
# [(6, 42), (6, 42, 23), (6, 42, 30), (6, 42, 34), (6, 42, 23, 10), (6, 42, 23, 47), (6, 42, 23, 47, 41), (6, 42, 23, 47, 41, 10), (6, 42, 23, 47, 41, 12), (6, 42, 23, 47, 41, 22), (6, 42, 23, 47, 41, 49)]
# node_1_path_tree before reordering
# [(48, 24), (48, 24, 12), (48, 24, 12, 32), (48, 24, 12, 32, 3), (48, 24, 12, 32, 25), (48, 24, 12, 32, 34), (48, 24, 12, 32, 3, 15), (48, 24, 12, 32, 3, 38), (48, 24, 12, 32, 3, 47)]
# reordering:
# [6, 42, 23, 30, 34, 10, 47, 41, 12, 22, 49, 48, 24, 32, 3, 25, 15, 38, 0, 1, 2, 4, 5, 7, 8, 9, 11, 13, 14, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 33, 35, 36, 37, 39, 40, 43, 44, 45, 46]
# node_0 after reordering: 0
# node_1 after reordering: 11
# node_0_path_tree after reordering
# [(0, 1, 2, 5), (0, 1, 2, 6)]
# node_1_path_tree after reordering
# [(11, 12, 8, 13)]

# %%
CONFIG_SPONTANEOUS = {
    'SEED': 0,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'DRIVE_AMPLITUDE': 4,
    'RUN_LENGTH_NO_DRIVE': 500,
    'TRIAL_LENGTH': 5,
    'N_REPEATS': 8,
    
    'FIG_SIZE': (12, 8),
}

# %%
softmax_random_basic_properties.spontaneous(CONFIG_SPONTANEOUS)

# %%
CONFIG_WEAKLY_DRIVEN = {
    'SEED': 0,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'WEAK_DRIVE_AMPLITUDE': 1,
    'STRONG_DRIVE_AMPLITUDE': 4,
    
    'PATH_MISMATCH_TIME': 2,
    
    'TRIAL_LENGTH': 5,
    'N_REPEATS': 4,
    
    'FIG_SIZE': (12, 12), 
}

# %%
softmax_random_basic_properties.weakly_driven(CONFIG_WEAKLY_DRIVEN)
