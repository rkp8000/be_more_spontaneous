# %%
# %matplotlib inline
import softmax_random_nonassociative_priming_replay

# %%
CONFIG_BASIC_REPLAY_EX = {
    'SEED': 2,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'GAIN_HIGH': 3,
    'GAIN_LOW': 1.5,
    
    'LINGERING_INPUT_VALUE': 2,
    'LINGERING_INPUT_TIMESCALE': 20,
    
    'STRONG_DRIVE_AMPLITUDE': 4,
    'WEAK_DRIVE_AMPLITUDE': 1,
    
    'TRIAL_LENGTH_TRIGGERED_REPLAY': 8,
    'RUN_LENGTH': 50,
    
    'FIG_SIZE': (15, 14)
}

# %%
softmax_random_nonassociative_priming_replay.basic_replay_ex(CONFIG_BASIC_REPLAY_EX)

# %%
CONFIG_BASIC_REPLAY_STATS = {
    'SEED': 0,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'GAIN_LOW': 1.5,
    'GAIN_HIGH': 3,
    
    'LINGERING_INPUT_VALUE': 2,
    'LINGERING_INPUT_TIMESCALE': 20,
    
    'STRONG_DRIVE_AMPLITUDE': 4,
    
    'T_SPONTANEOUS': 100,
    'SPONTANEOUS_REPEATS': 100,
    
    'FIG_SIZE': (15, 5)
}

# %%
softmax_random_nonassociative_priming_replay.basic_replay_stats(CONFIG_BASIC_REPLAY_STATS)

# %% [markdown]
# #### Stats
# Left: Probability that just-driven sequence corresponding to anatomical path replays after subsequently driving first element both with and without nonassociative priming (high gain).
# Middle and right: number of times we can expect just-driven sequence to replay spontaneously in the next 100 timesteps, with and without nonassociative priming (middle = low gain, right = high gain).

# %%
CONFIG_NOVEL_REPLAY = {
    'SEED': 5,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'W_WEAK': 1,
    
    'GAIN': 3,
    'REFRACTORY_STRENGTH': -1,
    
    'LINGERING_INPUT_VALUE': 2,
    'LINGERING_INPUT_TIMESCALE': 20,
    
    'STRONG_DRIVE_AMPLITUDE': 4,
    'WEAK_DRIVE_AMPLITUDE': 1,
    
    'TRIAL_LENGTH_TRIGGERED_REPLAY': 8,
    'RUN_LENGTH': 50,
    
    'FIG_SIZE_0': (15, 10),
    'FIG_SIZE_1': (15, 5),
}

# %%
softmax_random_nonassociative_priming_replay.novel_pattern_replay(CONFIG_NOVEL_REPLAY)
