# %%
# %matplotlib inline
import softmax_random_nonassociative_priming_learning

# %%
CONFIG = {
    'SEED': 0,
    
    'LOAD_FILE_NAME': 'softmax_random_network.npy',
    
    'W_WEAK': 1,
    
    'GAIN': 2,
    'REFRACTORY_STRENGTH': -1,
    
    'LINGERING_INPUT_VALUE': 2,
    'LINGERING_INPUT_TIMESCALE': 20,
    
    'W_MAX': 2,
    'ALPHA': 0.1,
    
    'STRONG_DRIVE_AMPLITUDE': 5,
    
    'RUN_LENGTH': 200,
    
    'N_REPEATS': 5,
    
    'FIG_SIZE_0': (10, 8)
}

# %%
softmax_random_nonassociative_priming_learning.novel_pattern_learning(CONFIG)
