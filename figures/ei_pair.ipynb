# %%
# %matplotlib inline
import ei_pair

# %%
CONFIG = {
    'SEED': None,
    
    'TAU_E': 5,
    'TAU_I': 25,
    'V_REST_E': 0,
    'V_REST_I': 0,
    'V_TH': 4,
    'STEEPNESS': 2.5,
    
    'W_EE': 5.5,
    'W_EI': -50.0,
    'W_IE': 10.0,
    
    'NOISE_LEVEL': 1,
    
    'DRIVE_AMPS': [10, 20, 30],
    'DRIVE_STARTS': [50, 200, 350],
    'DRIVE_ENDS': [55, 205, 355],
    
    'DURATION': 500,
    
    'FIG_SIZE': (15, 8),
    'FONT_SIZE': 20,
    
    'COLOR_CYCLE': ['k', 'r'],
}

# %%
ei_pair.main(CONFIG)
