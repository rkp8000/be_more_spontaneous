# %%
# %matplotlib inline
import sys
sys.path.append('/Users/rkp/Dropbox/Repositories')
sys.path.append('/Users/rkp/Dropbox/Repositories/be_more_spontaneous')

import test_networks as test
from unittest_jupyter import run

# %%
run(test.RateModelNetworkTestCase)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.608s
#
# OK

# %%
run(test.DiscreteTimeSquareLatticeTestCase)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
