# %%
from itertools import product as cproduct
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('/Users/rkp/Dropbox/Repositories/be_more_spontaneous')
# %matplotlib notebook

import fancy_raster

# %%
spikes = (np.random.rand(50, 12) > .9).astype(int)
drives = spikes.copy()
labels = list(cproduct(np.arange(4), ['r', 'g', 'b']))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2))
fancy_raster.by_row_and_color(ax, spikes, drives, labels)
# Out:
# <img src="data:image/png;base64,...">

# %%
spikes = (np.random.rand(50, 12) > .9).astype(int)
drives = spikes.copy()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
fancy_raster.by_row(ax, 2*spikes, 2*drives)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
drives[5:, :] = 0
fancy_raster.by_row_circles(ax, spikes, 1*drives, spike_marker_size=10, drive_marker_base_size=100)
# Out:
# <div id='18cdde19-49b6-4994-ae81-a5b1fddc0ede'></div>
